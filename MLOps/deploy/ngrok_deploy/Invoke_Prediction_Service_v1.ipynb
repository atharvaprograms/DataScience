# %% [markdown]
# # Invoking the Prediction Service
#
# **Author:** Manaranjan Pradhan</br>
# **Email ID:** manaranjan@gmail.com</br>
# **LinkedIn:** https://www.linkedin.com/in/manaranjanpradhan/</br>
# **Website:** www.manaranjanp.com
#
#
# ## Prepare the data

# %%
import requests, json

# %%
data = """{"Fuel_Type": "Diesel",
          "Transmission": "Manual",
          "Owner_Type": "First",
          "Age": 8,
          "Model": "ertiga",
          "KM_Driven": 87}"""

# %%
json_data = data.replace('\n', '').replace(' ','')

# %%
json_data
# Out:
# '{"Fuel_Type":"Diesel","Transmission":"Manual","Owner_Type":"First","Age":8,"Model":"ertiga","KM_Driven":87}'

# %%
response = requests.post('https://6073-34-125-4-15.ngrok-free.app/predict', data=json_data)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# ['Estimated Car Price: INR 6.0 Lakhs']
