# %% [markdown]
# # Invoking the Prediction Service
#
# **Author:** Manaranjan Pradhan</br>
# **Email ID:** manaranjan@gmail.com</br>
# **LinkedIn:** https://www.linkedin.com/in/manaranjanpradhan/</br>
# **Website:** www.manaranjanp.com
#
#
# ## Prepare the data

# %%
import requests, json

# %%
data = """{"sbp": 160,
          "tobacco": 12,
          "ldl": 5.73,
          "adiposity": 23.11,
          "famhist": "Present",
          "typea": 49,
          "obesity": 25.3,
          "alcohol": 97.2,
          "age": 52}"""

# %%
json_data = data.replace('\n', '').replace(' ','')

# %%
json_data
# Out:
# '{"sbp":160,"tobacco":12,"ldl":5.73,"adiposity":23.11,"famhist":"Present","typea":49,"obesity":25.3,"alcohol":97.2,"age":52}'

# %%
response = requests.post('https://3bc6-34-106-205-48.ngrok-free.app/predict', data=json_data)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# ['Patient has CHD (0/1) 1']
