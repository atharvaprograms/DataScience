# %% [markdown]
# # Loading the Model

# %%
class CarPredictionModel():
    
    def __init__(self, model, features, rmse):
        self.model = model
        self.features = features
        self.rmse = rmse

# %% [markdown]
# ## Sample Input

# %%
data = {'KM_Driven' : 55, 
        'Fuel_Type_Petrol' : 1,
        'Transmission_Manual': 1, 
        'Owner_Type_First': 1,
        'Age': 5,
        'Seats' : 5,
        'Model_swift': 1,
        'Mileage' : 16, 
        'Power': 90,
        'Location_Bangalore': 1}

# %% [markdown]
# ## Making Prediction

# %%
from joblib import load

# %%
model_object = load()

# %%
model_object.model

# %%
model_object.rmse

# %%
model_object.features

# %% [markdown]
# ### Create dictionary with all feaures

# %%
import pandas as pd

# %%
cars_df = pd.DataFrame()

# %%
cars_df

# %%
price = model_object.model.predict(cars_df)[0]

# %%
price

# %%
price - model_object.rmse, price + model_object.rmse
