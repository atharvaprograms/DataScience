# %% [markdown]
# # Time Series Forecast - Exponential Smoothing
#
# ### Kumar Rahul
#
# Forecasting the demand of services or products leads to better management of short term or long term planning. In this case, we are looking at the warranty related issues reported, on a particular brand of two-wheeler. The data is a monthly roll-up of approximately half a million issues reported by the customers over a four year period.
# We will be using Claim forecasting data in this exercise. Refer the **Exhibit 1** to understand the feature list. Use the data and answer the below questions.
#
# 1.	Load the time series dataset in Jupyter Notebook using pandas.
# 2.	Split the data into training set and test set. Use walk forward validation strategy for model building and evaluation.
# 3.	Given recent claim, what is the expected claim for the next time period? Build a model with statsmodel.api to forecast the amount claimed in next time step.
# 4.	 How do you interpret the model outcome? Report the model performance on the walk forward validation set.
#
# **Exhibit 1**
#
# |Sl. No.|Name of Variable|Variable Description|
# |----------|------------|---------------|
# |1	|date	|Date of Claim|
# |2	|rate	|Amount claimed|
# |3	|item	|Number of claims|

# %%
# load and clean-up data
from numpy import nan
from numpy import isnan
from pandas import to_numeric


import pandas as pd
import numpy as np
import warnings
from math import sqrt
from numpy import split
from numpy import array
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
#import matplotlib.pylab as plt

import statsmodels.tsa.holtwinters as hw
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm

# %%
##https://github.com/rahul235/ML_using_Python
url = "https://raw.githubusercontent.com/rahul235/ML_using_Python/master/Python_Code/Python_timeseries/Claim_forecasting/data/data_monthly.csv"
monthly_raw_df = pd.read_csv(url, sep=',', header=0, infer_datetime_format=True, 
                             index_col=['date'], 
                             parse_dates= ['date'],dayfirst=True)

# %%
monthly_raw_df.sort_index(inplace=True)
monthly_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 40 entries, 2014-03-31 to 2017-06-30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rate    40 non-null     float64
#  1   item    40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 960.0 bytes

# %% [markdown]
# The data for the first day and last day of CGM monitoring being trucated as it has not been captured for the full cycle.

# %%
monthly_filter_df = monthly_raw_df.filter(['rate'], axis =1)
monthly_filter_df['rate'] = monthly_filter_df['rate'].map(lambda x:str(x).replace(',', '')).astype(float)

# %%
monthly_filter_df = monthly_filter_df[(monthly_filter_df.index >='2014-03-01') & 
                                      (monthly_filter_df.index <= '2017-05-31')]

monthly_filter_df.info()

# %% [markdown]
# ## Problem Framing
#
#
# We will use the data to explore a very specific question; that is:
#
# **Given recent claim, what is the expected claim for the next time period?**
#
# Plot of the original data is shown below:

# %%
pyplot.figure(figsize = (18, 5))
pyplot.plot(monthly_filter_df, 'b-')
pyplot.title('Monthly amount claimed over a 3 year period')
# Out:
# Text(0.5, 1.0, 'Monthly amount claimed over a 3 year period')

# %% [markdown]
# ## Train and Test Sets
# We will use the first three years of data for training predictive models and the final year for evaluating models.
#
# The function split_filter_df() below splits the monthly data into train and test sets and organizes each into standard weeks.
#
# Specific row offsets are used to split the data using knowledge of the filter_df. The split filter_dfs are then organized into  data using the NumPy split() function.

# %%
def split_filter_df(data):
    split_point = len(data) - 10
    train, test = data[0:split_point], data[split_point:]
    return train, test

# %%
# load the new file
train, test = split_filter_df(monthly_filter_df)

# %%
# validate train data
print(train.shape)
train.head()
# Out:
# (30, 1)
#                   rate
# date
# 2014-03-31  2567662.19
# 2014-04-30  2752695.64
# 2014-05-31  2741751.40
# 2014-06-30  2459090.22
# 2014-07-31  2913370.48

# %%
# validate test data
print(test.shape)
test.head()
# Out:
# (10, 1)
#                   rate
# date
# 2016-09-30  4122453.71
# 2016-10-31  4037928.80
# 2016-11-30  4447380.34
# 2016-12-31  5288493.84
# 2017-01-31  5420980.66

# %% [markdown]
# ## Evaluation Metric
#
# Both Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE) can be used. Unlike MAE, RMSE is more punishing of forecast errors.
#
# The function evaluate_forecasts_rmse() and evaluate_forecasts_mape() is being used for evaluating model performance.

# %%
# evaluate one or more  forecasts against expected values
def evaluate_forecasts_rmse(actual):
    score_rmse = 0
    se = 0
    # calculate an RMSE score for each day
    for i in range(actual.shape[0]):
        # calculate mse
        se += (actual.iloc[i,0] - actual.iloc[i,1])**2
        # calculate rmse
    score_rmse = sqrt(se/actual.shape[0])
    return score_rmse

# %%
# evaluate one or more  forecasts against expected values
def evaluate_forecasts_mape(actual):
    score_mape = 0
    ape = 0
    for i in range(actual.shape[0]):
        # calculate mse
        ape += np.abs(((actual.iloc[i,0] - actual.iloc[i,1])/actual.iloc[i,0]))
        # calculate mape
    score_mape = (ape)/actual.shape[0]
    return actual, score_mape

# %% [markdown]
# ## Develop Basic Model
#
# The model developed here is ExponentialSmooting (TES).
#
# * SES - SimpleExpSmoothing
# * Holt - DES
# * ExponentialSmoothing - TES

# %% [markdown]
# ### Walk-Forward validation

# %%
# evaluate a single model
def evaluate_model(model_func, train, test,alpha,beta,gamma,season):
    # history is a list of  data
    history = train.filter(['rate'], axis = 1)
    #print(history)
    # walk-forward validation over each week
    predictions = list()
    for i in range(len(test)):
        # predict the week
        yhat_sequence = model_func(history.values, alpha, beta, gamma, season)
        # store the predictions
        predictions.append(yhat_sequence)      
        # get real observation and add to history for predicting the next week
        history = history.append(test.iloc[[i]])
    predictions = array(predictions)
    test['prediction'] = predictions
    # evaluate predictions days for each week
    actual, score_mape = evaluate_forecasts_mape(test[:])
    score_rmse = evaluate_forecasts_rmse(test[:])
    return actual, score_mape, score_rmse

# %%
# forecast
def exp_forecast(history, alpha, beta, gamma, season):
    # define the model
    model = ExponentialSmoothing(history, seasonal = season, seasonal_periods=12)
    # fit the model
    model_fit = model.fit(smoothing_level=alpha, smoothing_slope=beta, smoothing_seasonal = gamma, optimized=True)
    # make forecast
    yhat = model_fit.forecast(steps=1)[0]
    return yhat

# %%
def del_column(test):
    for n in test.columns:
        if n =='prediction':
            test.drop('prediction', axis = 1, inplace=True)

# %%
# define the names and functions for the models which is to be evaluated
models = dict()
models['ExponentialSmoothening'] = exp_forecast

import itertools
alpha = [0.2,0.4,0.6, 0.8]
beta  = [0.4,0.5, 0.6]
gamma = [0.1, 0.5]
season = ['add','mul']

grid_values = list(itertools.product(alpha, beta, gamma,season))
warnings.filterwarnings("ignore")

# evaluate each model
for name, func in models.items():
    best_mape,best_rmse, best_alpha, best_beta, best_gamma, best_season = float("inf"), float("inf"),float("inf"),float("inf"),float("inf"), str()
    
    for i in range(0, len(grid_values)):
        alpha = grid_values[i][0]
        beta = grid_values[i][1]
        gamma = grid_values[i][2]
        season = grid_values[i][3]
        del_column(test)
        try:
            actual, score_mape, score_rmse= evaluate_model(func, train, test,alpha, beta, gamma,season)
            if score_rmse < best_rmse:
                best_rmse, best_mape, best_alpha, best_beta, best_gamma, best_season = score_rmse, score_mape, alpha, beta, gamma,season
            print('alpha = %.2f beta = %.2f gamma = %.2f MAPE=%.5f RMSE=%.4f Model=%s' % (alpha, beta, gamma,score_mape,score_rmse, season))
        except:
            continue
    print('Best alpha = %.2f beta = %.2f gamma = %.2f MAPE=%.5f RMSE=%.5f Model = %s' % (best_alpha, best_beta, best_gamma,best_mape, best_rmse, season))
# Out:
# alpha = 0.20 beta = 0.40 gamma = 0.10 MAPE=1.46183 RMSE=1247121.6290 Model=add
# alpha = 0.20 beta = 0.40 gamma = 0.10 MAPE=1.42939 RMSE=1596206.8041 Model=mul
# alpha = 0.20 beta = 0.40 gamma = 0.50 MAPE=1.46195 RMSE=1237275.2204 Model=add
# alpha = 0.20 beta = 0.40 gamma = 0.50 MAPE=1.40445 RMSE=1218715.1569 Model=mul
# alpha = 0.20 beta = 0.50 gamma = 0.10 MAPE=1.46183 RMSE=1247121.6290 Model=add
# alpha = 0.20 beta = 0.50 gamma = 0.10 MAPE=1.42939 RMSE=1596206.8041 Model=mul
# alpha = 0.20 beta = 0.50 gamma = 0.50 MAPE=1.46195 RMSE=1237275.2204 Model=add
# alpha = 0.20 beta = 0.50 gamma = 0.50 MAPE=1.40445 RMSE=1218715.1569 Model=mul
# alpha = 0.20 beta = 0.60 gamma = 0.10 MAPE=1.46183 RMSE=1247121.6290 Model=add
# alpha = 0.20 beta = 0.60 gamma = 0.10 MAPE=1.42939 RMSE=1596206.8041 Model=mul
# alpha = 0.20 beta = 0.60 gamma = 0.50 MAPE=1.46195 RMSE=1237275.2204 Model=add
# alpha = 0.20 beta = 0.60 gamma = 0.50 MAPE=1.40445 RMSE=1218715.1569 Model=mul
# alpha = 0.40 beta = 0.40 gamma = 0.10 MAPE=1.35761 RMSE=1186347.1221 Model=add
# alpha = 0.40 beta = 0.40 gamma = 0.10 MAPE=1.30513 RMSE=1154624.9851 Model=mul
# alpha = 0.40 beta = 0.40 gamma = 0.50 MAPE=1.33643 RMSE=1166408.3270 Model=add
# alpha = 0.40 beta = 0.40 gamma = 0.50 MAPE=1.35954 RMSE=1565475.4166 Model=mul
# alpha = 0.40 beta = 0.50 gamma = 0.10 MAPE=1.35761 RMSE=1186347.1221 Model=add
# alpha = 0.40 beta = 0.50 gamma = 0.10 MAPE=1.30513 RMSE=1154624.9851 Model=mul
# alpha = 0.40 beta = 0.50 gamma = 0.50 MAPE=1.33643 RMSE=1166408.3270 Model=add
# alpha = 0.40 beta = 0.50 gamma = 0.50 MAPE=1.35954 RMSE=1565475.4166 Model=mul
# alpha = 0.40 beta = 0.60 gamma = 0.10 MAPE=1.35761 RMSE=1186347.1221 Model=add
# alpha = 0.40 beta = 0.60 gamma = 0.10 MAPE=1.30513 RMSE=1154624.9851 Model=mul
# alpha = 0.40 beta = 0.60 gamma = 0.50 MAPE=1.33643 RMSE=1166408.3270 Model=add
# alpha = 0.40 beta = 0.60 gamma = 0.50 MAPE=1.35954 RMSE=1565475.4166 Model=mul
# alpha = 0.60 beta = 0.40 gamma = 0.10 MAPE=1.19705 RMSE=1077843.2159 Model=add
# alpha = 0.60 beta = 0.40 gamma = 0.10 MAPE=1.18073 RMSE=1076628.0051 Model=mul
# alpha = 0.60 beta = 0.40 gamma = 0.50 MAPE=1.17338 RMSE=1059824.0164 Model=add
# alpha = 0.60 beta = 0.40 gamma = 0.50 MAPE=1.19009 RMSE=1069844.8600 Model=mul
# alpha = 0.60 beta = 0.50 gamma = 0.10 MAPE=1.19705 RMSE=1077843.2159 Model=add
# alpha = 0.60 beta = 0.50 gamma = 0.10 MAPE=1.18073 RMSE=1076628.0051 Model=mul
# alpha = 0.60 beta = 0.50 gamma = 0.50 MAPE=1.17338 RMSE=1059824.0164 Model=add
# alpha = 0.60 beta = 0.50 gamma = 0.50 MAPE=1.19009 RMSE=1069844.8600 Model=mul
# alpha = 0.60 beta = 0.60 gamma = 0.10 MAPE=1.19705 RMSE=1077843.2159 Model=add
# alpha = 0.60 beta = 0.60 gamma = 0.10 MAPE=1.18073 RMSE=1076628.0051 Model=mul
# alpha = 0.60 beta = 0.60 gamma = 0.50 MAPE=1.17338 RMSE=1059824.0164 Model=add
# alpha = 0.60 beta = 0.60 gamma = 0.50 MAPE=1.19009 RMSE=1069844.8600 Model=mul
# alpha = 0.80 beta = 0.40 gamma = 0.10 MAPE=1.03160 RMSE=957681.7339 Model=add
# alpha = 0.80 beta = 0.40 gamma = 0.10 MAPE=1.04962 RMSE=982012.0915 Model=mul
# alpha = 0.80 beta = 0.40 gamma = 0.50 MAPE=1.02280 RMSE=967223.2287 Model=add
# alpha = 0.80 beta = 0.40 gamma = 0.50 MAPE=1.07987 RMSE=1002504.2420 Model=mul
# alpha = 0.80 beta = 0.50 gamma = 0.10 MAPE=1.03160 RMSE=957681.7339 Model=add
# alpha = 0.80 beta = 0.50 gamma = 0.10 MAPE=1.04962 RMSE=982012.0915 Model=mul
# alpha = 0.80 beta = 0.50 gamma = 0.50 MAPE=1.02280 RMSE=967223.2287 Model=add
# alpha = 0.80 beta = 0.50 gamma = 0.50 MAPE=1.07987 RMSE=1002504.2420 Model=mul
# alpha = 0.80 beta = 0.60 gamma = 0.10 MAPE=1.03160 RMSE=957681.7339 Model=add
# alpha = 0.80 beta = 0.60 gamma = 0.10 MAPE=1.04962 RMSE=982012.0915 Model=mul
# alpha = 0.80 beta = 0.60 gamma = 0.50 MAPE=1.02280 RMSE=967223.2287 Model=add
# alpha = 0.80 beta = 0.60 gamma = 0.50 MAPE=1.07987 RMSE=1002504.2420 Model=mul
# Best alpha = 0.80 beta = 0.40 gamma = 0.10 MAPE=1.03160 RMSE=957681.73385 Model = mul

# %% [markdown]
# ### Use the best parameter to run the model

# %%
models = dict()
models['ExponentialSmoothening'] = exp_forecast

# evaluate each model
for name, func in models.items():
    alpha = 0.8
    beta = 0.4
    gamma = 0.1
    season = 'mul'
    del_column(test)
    actual, score_mape, score_rmse= evaluate_model(func, train, test,alpha, beta, gamma,season)
    print('MAPE=%.5f RMSE=%.5f' % (best_mape, best_rmse))
# Out:
# MAPE=1.03160 RMSE=957681.73385

# %%
actual
# Out:
#                   rate    prediction
# date
# 2016-09-30  4122453.71  5.362257e+06
# 2016-10-31  4037928.80  4.172238e+06
# 2016-11-30  4447380.34  4.548747e+06
# 2016-12-31  5288493.84  5.002168e+06
# 2017-01-31  5420980.66  4.642469e+06
# 2017-02-28  5181408.87  4.913870e+06
# 2017-03-31  5277467.13  5.096020e+06
# 2017-04-30  3739654.03  4.536861e+06
# 2017-05-31  2498902.93  3.759129e+06
# 2017-06-30   246201.92  2.496042e+06

# %%
#actual.to_csv('holts_winter_monthly_forecast.csv')

# %% [markdown]
# ## Exercise
#
# 1. Trend is also a parameter in `ExponentialSmoothing` model. However, we have not defined that in grid_values.  Modify the code to include trend in the grid search for ExponentialSmoothing Model.
# 2. Develop SES and Holt (DES) model by modifying the code in this notebook.
# 3. Compare the MAPE for SES, DES and TES model. Which model will you go ahead with?
